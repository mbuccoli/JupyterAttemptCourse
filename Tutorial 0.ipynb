# %% [markdown]
# # Tutorial Number 0

# %% [markdown]
# This is the very first tutorial for Jupyter on Github, just to show the potentials of the tool for building interactive Lecture Notes

# %% [markdown]
# This example is uploaded on GitHub at this <a href="https://github.com/mbuccoli/JupyterAttemptCourse/blob/master/Tutorial%200.ipynb">link</a>. The example can be statically viewed on GitHub or dinamically modified by students, in case of need

# %% [markdown]
# Moreover, it has other fancy tool, such as inline Latex equation editor, like the most beautiful equation in the world, i.e., $e^{i\pi}=-1$ or more complex equations:
# \begin{equation} \large
# E=\sum_{n=0}^{N} x[n]^2
# \end{equation}

# %% [markdown]
# Now, we had a good introduction, let's go with some real code please

# %% [markdown]
# ## Importing packages

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(0,100,1000)
y=np.power(x,2)
plt.figure(figsize=(10,7))
plt.plot(x,y,lw=5)
plt.xlabel('x')
plt.ylabel('$x^2$')
plt.show()

# %% [markdown]
# The %matplotlib inline meta-command is very helpful for showing the plots inline, as a figure in the webpage

# %% [markdown]
# ## Insert Media
